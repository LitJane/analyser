# %%
import logging
import platform
import sys
import os
import seaborn as sns
import matplotlib.pyplot as plt
from IPython.display import display, Markdown
from datetime import datetime
import tensorflow as tf
# import datetime

logger = logging.getLogger('retrain_ipynb')
logger.setLevel(logging.DEBUG)


ch = logging.StreamHandler()
ch.setLevel(logging.DEBUG)
formatter = logging.Formatter('%(levelname)s - %(asctime)s - %(name)s - %(message)s')
ch.setFormatter(formatter)
logger.addHandler(ch)
logger.debug('--=logging started=--')

# %%
nb_dir = os.path.split(os.getcwd())[0]
if nb_dir not in sys.path:
    sys.path.append(nb_dir)
    
import analyser.hyperparams 





#FORCE CPU
# os.environ['CUDA_VISIBLE_DEVICES'] = '-1'
# tf.config.set_visible_devices([], 'GPU')
# tf.debugging.set_log_device_placement(True)

# %%
ids_all='''


63ac1fab862ea92bf713c51e
63ac1faa862ea92bf713c50d
63ac1fa9862ea92bf713c509
63ac1faa862ea92bf713c515 
63ac1faa862ea92bf713c51d
63ac1fac862ea92bf713c534
63ac1fa9862ea92bf713c50a
63ac1fac862ea92bf713c536
63ac1fab862ea92bf713c522
63ac1fad862ea92bf713c53f

6391a7481864c6df4d29f30b
63a43056beaa9eeec65ecafb
63a430a6beaa9eeec65ecb0b 
63a43092beaa9eeec65ecb09
63a4306dbeaa9eeec65ecafe
63a430dbbeaa9eeec65ecb12 
63a430e6beaa9eeec65ecb18
63a430b4beaa9eeec65ecb0d 


63c506ede2456d59975e15bf
63c506ede2456d59975e15c6
63c506bde2456d59975e110a
63c506cbe2456d59975e12ae
63c506bde2456d59975e1107
63c506cbe2456d59975e12aa
63c506cbe2456d59975e12a6
63c506bce2456d59975e10f9  
63c506cbe2456d59975e12a6
63c506bce2456d59975e10f9 
63c506cae2456d59975e129a 
63c506bce2456d59975e10ef
63c506b4e2456d59975e103d
63c506ace2456d59975e0f9b
63c506c9e2456d59975e127d
63c506bce2456d59975e10ef
63c506ace2456d59975e0f9b
63c506c9e2456d59975e127d
63c506c8e2456d59975e123e
63c506c9e2456d59975e1276
63c506bbe2456d59975e10d9
63c506afe2456d59975e0fca
63c506bbe2456d59975e10dd  
63c506c9e2456d59975e1276
63c506bbe2456d59975e10d9
63c506bae2456d59975e10c1  


63c506e5e2456d59975e1570  
63c506b0e2456d59975e0fea   
63c506c7e2456d59975e1232  
63c506c1e2456d59975e1187  
63c506c0e2456d59975e116a  
63c506c1e2456d59975e118c  
63c506dbe2456d59975e143d  
63c506c0e2456d59975e1170  
63c506c5e2456d59975e1201  
63c506bee2456d59975e1139  
63c506b9e2456d59975e10ae  
63c506e4e2456d59975e1550  
63c506e4e2456d59975e1550  
63c506c6e2456d59975e121e  
63c506dbe2456d59975e143c  
63c506ece2456d59975e15b6  
63c506c9e2456d59975e1266  
63c506e5e2456d59975e155d  
63c506dfe2456d59975e14ac  
63c506b4e2456d59975e1041   
63c506b0e2456d59975e0fe6  
63c506b5e2456d59975e1042  
63c506ebe2456d59975e1596  
63c506dce2456d59975e1456  
63c506c0e2456d59975e116d   
63c506d6e2456d59975e13a2   
63c506ebe2456d59975e15a2  
63c506d1e2456d59975e1337  
63c506d2e2456d59975e1346  
63c506c7e2456d59975e1231   
63c506c6e2456d59975e1222  
63c506cae2456d59975e1284   
63c506b7e2456d59975e107e  
63c506aae2456d59975e0f82  
63c506aee2456d59975e0fc8   
63c506b1e2456d59975e0fed  
63c506c5e2456d59975e11fe  
63c506c0e2456d59975e1185  
63c506d8e2456d59975e13f2   


63c506d4e2456d59975e1386 
63c506d9e2456d59975e13ff 
63c506bbe2456d59975e10e2 
63c506dee2456d59975e148b 
63c506e0e2456d59975e14e2 
63c506e1e2456d59975e14e4 
63c506b3e2456d59975e102b 
63c506e5e2456d59975e156b 
63c506c4e2456d59975e11e3 
63c506c2e2456d59975e11a8 
63c506c9e2456d59975e127f 
63c506cfe2456d59975e12fa 
63c506e3e2456d59975e1519 
63c506c0e2456d59975e1182 
63c506d0e2456d59975e1319 
63c506d1e2456d59975e1341 
63c506c8e2456d59975e1259 
63c506c1e2456d59975e1194 
63c506dde2456d59975e146a 
63c506cde2456d59975e12e6 
63c506cfe2456d59975e1301 
63c506abe2456d59975e0f95 
63c506b8e2456d59975e108b 
63c506dde2456d59975e1469 
63c506bbe2456d59975e10d7 
63c506dde2456d59975e1469 


63c506ebe2456d59975e1599
63c506b9e2456d59975e10aa
63c506bde2456d59975e1118
63c506b9e2456d59975e10b5
63c506cce2456d59975e12c3
63c506b0e2456d59975e0fe7
63c506bde2456d59975e111f
63c506bde2456d59975e1120
63c506ace2456d59975e0f9e
63c506bde2456d59975e1122
63c506b5e2456d59975e1059
63c506bde2456d59975e1123
63c506bee2456d59975e112a
63c506abe2456d59975e0f8f
63c506b6e2456d59975e105d
63c506bfe2456d59975e1144
63c506bfe2456d59975e1147
63c506bfe2456d59975e114c
63c506b6e2456d59975e1070
63c506abe2456d59975e0f92
63c506b1e2456d59975e1005
63c506b7e2456d59975e107a
63c506b7e2456d59975e107b
63c506c0e2456d59975e117b
63c506c1e2456d59975e1186
63c506b2e2456d59975e1007
63c506c1e2456d59975e1188
63c506b2e2456d59975e1009
63c506c1e2456d59975e119b
63c506c1e2456d59975e119f
63c506c2e2456d59975e11a3
63c506b8e2456d59975e109e
63c506c2e2456d59975e11ae
63c506aee2456d59975e0fc1
63c506b3e2456d59975e1019
63c506c3e2456d59975e11c3
63c506b9e2456d59975e10a8
63c506c3e2456d59975e11d2
63c506c3e2456d59975e11d6
63c506c4e2456d59975e11da
63c506c4e2456d59975e11dd


63c506c9e2456d59975e1271
63c506bbe2456d59975e10d4
63c506b4e2456d59975e103d
63c506c8e2456d59975e1261
63c506c7e2456d59975e1223
63c506bae2456d59975e10bf
63c506c8e2456d59975e125c
63c506c8e2456d59975e1256
63c506c9e2456d59975e1271
63c506bbe2456d59975e10d4
63c506b4e2456d59975e103d
63c506c8e2456d59975e1261
63c506aee2456d59975e0fc5
63c506c8e2456d59975e125c
63c506c8e2456d59975e1256
63c506afe2456d59975e0fcd
63c506c8e2456d59975e1251
63c506abe2456d59975e0f8b
63c506dee2456d59975e1488
63c506c8e2456d59975e123e
63c506b9e2456d59975e10af
63c506c8e2456d59975e1256
63c506afe2456d59975e0fcd
63c506c8e2456d59975e1251
63c506abe2456d59975e0f8b
63c506c8e2456d59975e123e
63c506c4e2456d59975e11da
63c506dce2456d59975e1459
63c506afe2456d59975e0fca
63c506c3e2456d59975e11d2
63c506b9e2456d59975e10a8
63c506c7e2456d59975e123a
63c506afe2456d59975e0fca
63c506dae2456d59975e1415
63c506b8e2456d59975e109e
63c506c7e2456d59975e122d
63c506c2e2456d59975e11a3
63c506b8e2456d59975e109c
63c506c1e2456d59975e1186
63c506bae2456d59975e10bc
63c506d7e2456d59975e13d6
63c506c1e2456d59975e1188
63c506b4e2456d59975e102f
63c506c7e2456d59975e1223
63c506bae2456d59975e10c1
63c506bae2456d59975e10c2
63c506bae2456d59975e10bf
63c506bae2456d59975e10bc
63c506c5e2456d59975e1202
63c506d5e2456d59975e1394
63c506b9e2456d59975e10b3
63c506c4e2456d59975e11ee
63c506b9e2456d59975e10af
63c506c4e2456d59975e11ea
63c506b1e2456d59975e1004
63c506c5e2456d59975e1202
63c506bfe2456d59975e1147

63c506c3e2456d59975e11d2
63c506ace2456d59975e0f9e
63c506c3e2456d59975e11d6
63c506cfe2456d59975e1311
63c506c4e2456d59975e11ea
63c506c4e2456d59975e11ee
63c506b3e2456d59975e102a
63c506b9e2456d59975e10b3
63c506c5e2456d59975e1202
63c506bfe2456d59975e1147
63c506b9e2456d59975e10af
63c506b9e2456d59975e10b3
63c506c5e2456d59975e1202
63c506aee2456d59975e0fc5
63c506bae2456d59975e10bc 
'''
ids = ids_all.split()
ids = sorted(list(set(ids)))
len(ids)

# %%
ids_fixeded='''
5fe48218b770574a005555bf
5fe4821ab770574a0055562e
5fe4821db770574a005556be
5fe4821fb770574a00555747
5fe48220b770574a00555790
5fc7a035c54bc33809e261d7
5fca2ab19083b679224c7646
5fe48220b770574a005557af
5fe4821fb770574a00555735
5fe4821bb770574a0055565a
5fe4821bb770574a00555678
5fe4821ab770574a00555634
5fe48221b770574a005557da
5fe48222b770574a0055580f
5fe4821eb770574a00555704
5fe48222b770574a00555812
5fe4821bb770574a00555659
5fe48222b770574a005557ee
5fe4821fb770574a0055572e
5fe4821eb770574a00555708
5fe4821eb770574a00555724
5fbbbd1da2b4551c06107a7d
5fb3d79e78df3635f5441d1e
5feb3e50bd24992aa31040e2
62948fc7df54d406a99b15df
63ce4b18e83d1ee490f4017c
63ce4b16e83d1ee490f4016a
5fb6751033c72547b755016d
5fe48217b770574a00555585
5fe48218b770574a005555c2
5fdb2141542ce403c92b4576
638085a36a07f3e980b2c61c
5fe34f64b770574a005553e2
5fbbe46ca2b4551c06107c15
5fe4821ab770574a00555614
5fe4821eb770574a005556f6
5fe48222b770574a005557e7
5fe4821bb770574a00555679
5fe34f64b770574a005553e6
5ec2b8db665f7603e03b1281
5fb3d49c78df3635f5441b64
62874fcd4d1bfe5e5b297df0
62838b2e4d1bfe5e5b297ddb
5fdb2143542ce403c92b45af
5fe4821eb770574a005556f5
5fe48217b770574a0055557d
63ce4b16e83d1ee490f40161
638f0a81b1363747e929f2fb
62cd547a32fe0e1ffcc28116
5fb3b99000881c332b56735b
5fca2aae9083b679224c7614
637e0669c15a83c52bb2bfbf
5fb3b97e00881c332b56729f
6256844aa45b04eaf98b4155
63c92b5dfb21317f1d5e0f83
6391bbeb1002115a6029f397
6391a4451002115a6029f38b
639194f91002115a6029f385
639191531002115a6029f37f
6380857d6a07f3e980b2c332
5fbf75af5d05d73d0295fa88
5fbbe467a2b4551c06107afc
5fbf75af5d05d73d0295fa89
5fbbe46da2b4551c06107c80
5fca2acd9083b679224c77da
5fb3d7a678df3635f5441e39
63908ca3a1bded13e629f2dc
6380855d6a07f3e980b2c073
611f87d5ddbe0a842820e64e
63ce4a56e83d1ee490f3f790
5fb3d7a978df3635f5441ebb
5fb3d4a178df3635f5441c70
6294ae67df54d406a99b1631
6285f525f098f73e14297f93
5fe4821eb770574a005556fe
5fe4821eb770574a00555718
62cd56cb32fe0e1ffcc28118
63d24bf33554f2343d832c9d
5fb3d7a278df3635f5441d7b
5fe07edb167d501e4c4e6065
5fe48219b770574a005555fe
5fe4821bb770574a0055565e
5fb3d7a678df3635f5441e06
5fe48218b770574a005555c6
5fe4821db770574a005556dd
5fe48219b770574a005555e8
5fe4821ab770574a00555618
5fe48219b770574a00555601
5fe4821fb770574a0055574b
5fe4821ab770574a00555638
5fe48218b770574a005555b7
5fe34f63b770574a005553c3
5fbbe466a2b4551c06107ad1
5fbbe46aa2b4551c06107bc6
5fb3d7a578df3635f5441def
5fc635251d0a1603c7a0c93c
5fca2ab09083b679224c7630
5fbbe46da2b4551c06107c76
5fbbe46ca2b4551c06107c12
5fb3d4a178df3635f5441c6f
5fe4821ab770574a00555652
5fe4821fb770574a00555755
5fe48219b770574a005555e6
5fe4821ab770574a00555632
5fe4821bb770574a00555673
5fe48221b770574a005557d9
5fe48220b770574a00555781
5fe48217b770574a0055559f
5fe4821db770574a005556c6
60002adfb08473039387bcbe
5fe07edb167d501e4c4e606b
5fbbe467a2b4551c06107b01
5fdb2142542ce403c92b4582
635fa420bf4cb23cbb39282d
629dccf80806e3924ebafc70
638f0a81b1363747e929f304
6166e28787f1d9065bb8b943
612de8b04f22ff1b7e02fcda
6128931bb8ceba5a6803d26a
61289013b8ceba5a6803d266
6380859e6a07f3e980b2c5c4
5ec2b8da665f7603e03b1265
5ebd312d665f7603e03b11d2
5fb674fa33c72547b754ffa2
5fbbbd13a2b4551c061078bf
634018f59d08c565cfa1233d
63dccb412c90db0b7a62aa8d
63dccb422c90db0b7a62aab1
5fca2aad9083b679224c7609
634022659d08c565cfa1233f
638085ae6a07f3e980b2c77d
6285f51ff098f73e14297ebd
5ec2b8da665f7603e03b127e
5ec2b8d9665f7603e03b122e
5ec2b8d8665f7603e03b121c
5e2ea6ca73698e191112bee8
5fc7a031c54bc33809e26182
60ed762acddbb3c487368c4d
5fe48220b770574a0055578c
5fbbe466a2b4551c06107ad5
5fbbbd19a2b4551c061079c5
5fbbe467a2b4551c06107b06
633d4fa09d08c565cfa12315
5fc7a031c54bc33809e2617f
5fbbe46da2b4551c06107c95
5feb3e51bd24992aa310410d
5fca2ab09083b679224c7624
60f6cae9d624fbd2b4175dca
5fe34f63b770574a005553ca
5fe34f63b770574a005553c6
5fe34f64b770574a005553e3
5fe34f63b770574a005553cf
60f5c5b6d624fbd2b4175db8
5fbbe46ba2b4551c06107bda
5fbbe46ca2b4551c06107c2e
5ec2b8da665f7603e03b126a
5ebaa580665f7603e03b11a9
5ec2b8d8665f7603e03b1224
5ec2b8d8665f7603e03b1228
5ec2b8d9665f7603e03b1243
5ec2b8d9665f7603e03b1241
5ec2b8da665f7603e03b1264
5ec2b8da665f7603e03b1254
5ec2b8da665f7603e03b125c
5ec2b8da665f7603e03b1256
5ec2b8d9665f7603e03b1248
5ec2b8da665f7603e03b1252
5e257bb473698e191112be7b
615ac8cf8f3b0514f3f423f8
5fbbbd1ca2b4551c06107a5f
5fb3d7a378df3635f5441d8e
5fb3d7a178df3635f5441d6a
6152e3798558145da68d8788
612de89f4f22ff1b7e02fcd7
6380855c6a07f3e980b2c061
62c54895e599c73b751b7974
6391b4771864c6df4d29f332
63908ca4a1bded13e629f2e4
5fb6750a33c72547b755010d
5fbbe46ca2b4551c06107c21
5fb3d4a078df3635f5441c32
638085686a07f3e980b2c124
5fe48218b770574a005555db
6152e3af8558145da68d8790
6152e3a38558145da68d878d
6152e36c8558145da68d8785
638085766a07f3e980b2c275
638085756a07f3e980b2c266
5fbbe468a2b4551c06107b52
5fbbe46da2b4551c06107c68
5fb3d7a078df3635f5441d42
62d149484ae369b4976e31ff
62d149474ae369b4976e31f6
5fdb213e542ce403c92b4524
5fb3d4a278df3635f5441ca6
5fb376e2d8c9df1ed123726a
5fdb2140542ce403c92b4549
5fbbe466a2b4551c06107adc
5fe48218b770574a005555d3
5fe34f63b770574a005553d2
5fdb213c542ce403c92b4511
5fdb2145542ce403c92b45ec
5fdb213d542ce403c92b4518
5fbbe469a2b4551c06107b81
5fbbe469a2b4551c06107b85
5fbbe46da2b4551c06107c8b
5fbbe466a2b4551c06107ac7
5feb3e50bd24992aa31040e6
63c506c9e2456d59975e1277
6166d9f787f1d9065bb8b933
638085a16a07f3e980b2c5f0
6152e5cc8558145da68d8797
638085766a07f3e980b2c27a
638085746a07f3e980b2c247
638085746a07f3e980b2c246
5fb3d7a678df3635f5441e35
5fb3b97f00881c332b5672d6
5fdb2143542ce403c92b45a1
6398483d4b01c8adaa5a4ef4
6347b28d06011e34b4f15df7
5fc7a031c54bc33809e2617d
5fe4821ab770574a00555656
5fe4821db770574a005556d1
5fe4821fb770574a00555741
5fca2ac89083b679224c7786
5fca2ab09083b679224c7638
5fb399dd39d5e82e90818477
5fc7a037c54bc33809e26212
6340086b9d08c565cfa12337
63453826172785f510f15e11
639316f61002115a6029f3c8
6380857e6a07f3e980b2c343
638085ac6a07f3e980b2c733
638085a36a07f3e980b2c623
6246a1b325a983726c76938a
5fb376e2d8c9df1ed123727e
5fdb2147542ce403c92b4617
5fca2ac79083b679224c7750
5fca2ac99083b679224c77b0
63908ca4a1bded13e629f2ea
5ec2b8da665f7603e03b1255
'''

# %%
ids = ids_fixeded.split()
ids = sorted(list(set(ids)))
print(len(ids))

errors_report_file_prefix = "fixed_markup_errors"
errors_report_metric_prefix = "user_fixed"
user_docs_ids = ids
# %run -i -t validate_markup.ipynb
del user_docs_ids

# %%
# ids

# %%
# ids

errors_report_file_prefix = "495_markup_errors"
errors_report_metric_prefix = "#495"
user_docs_ids = ids
# %run -i -t validate_markup.ipynb
del user_docs_ids

# %%
# if False:
#     from pathlib import Path
#     cache_dir = Path(analyser.hyperparams.work_dir) / 'datasets'
#     for id in ids:
#         fil = cache_dir / f'{id}-datapoint-embeddings.npy'

#         if fil.is_file():
#             os.remove(fil) 
#             print('removing', id, fil)

# %%
# !ls -la /root/artem/work/datasets

# %%
# ids

import pandas as pd


def load_docs_data(ids, df, col_suffix):
  for _id in ids:
    doc = get_doc_by_id(ObjectId(_id))
    jd = DbJsonDoc(doc)
#     print(jd.get_attribute_value('number'))
    
    df.at[ _id, f'analyze_timestamp{col_suffix}']=jd.analysis['analyze_timestamp']
    df.at[ _id, f'number{col_suffix}']=jd.get_attribute_value('number')
    df.at[ _id, f'subject{col_suffix}']=jd.get_attribute_value('subject')
    df.at[ _id, f'amount_netto{col_suffix}'] = jd.get_attributes_tree().get('price', {}).get('amount_netto', {}).get('value', None)
    df.at[ _id, f'amount_brutto{col_suffix}'] = jd.get_attributes_tree().get('price', {}).get('amount_brutto', {}).get('value', None)
    df.at[ _id, f'amount{col_suffix}'] = jd.get_attributes_tree().get('price', {}).get('amount', {}).get('value', None)
    df.at[ _id, f'vat{col_suffix}'] = jd.get_attributes_tree().get('price', {}).get('vat', {}).get('value', None)
    df.at[ _id, f'currency{col_suffix}'] = jd.get_attributes_tree().get('price', {}).get('currency', {}).get('value', None)
    df.at[ _id, f'analysis.version{col_suffix}'] = jd.analysis['version']
    
     
    span = jd.get_attributes_tree().get('subject', {}).get('span', None)
    
    if span:
        tm = jd.get_tokens_map_unchaged()

        quote = tm.text_range(span)
    
        df.at[_id,f'subject quote{col_suffix}'] = quote[:200]

# %%
df=None
fn = '495-contracts-re-analyze-subj.csv'
df = pd.read_csv(fn, index_col=0)
df['subject quote _old']=''

# %%
df

# %%
if df is None:
    df=pd.DataFrame()
    load_docs_data(ids, df, ' _old')
    df = df.sort_values(['subject _old', 'subject quote _old'])
    df.to_csv('495-contracts-re-analyze-subj.csv')

# %%
from bson import ObjectId

from analyser.finalizer import get_doc_by_id, get_audit_by_id
from analyser.log import logger
from analyser.parsing import AuditContext
from analyser.persistence import DbJsonDoc
from analyser.runner import BaseProcessor, document_processors, CONTRACT


def re_analyze_contract(_id):
  processor: BaseProcessor = document_processors[CONTRACT]
  # doc = get_doc_by_id(ObjectId('638f0a81b1363747e929f304'))
  doc = get_doc_by_id(ObjectId(_id))
  #
  if doc is None:
    raise RuntimeError(f"doc with UID {_id} is not in the DB")

  audit = get_audit_by_id(doc['auditId'])
  # print(audit)

  jdoc = DbJsonDoc(doc)
  logger.info(f'......pre-processing {jdoc._id}')
  ctx = AuditContext()
  ctx.audit_subsidiary_name = audit.get('subsidiary', {}).get('name')
  processor.preprocess(jdoc, context=ctx)
  processor.process(jdoc, audit, ctx)

# %%
df.loc[ids[0]]

# %% [markdown]
# # Analysis

# %%
# %%time


from IPython.display import clear_output

# for i in range(10):
   
#     print("Hello World!")
    
    
s = datetime.today()
logger.info(f're-analyse start  {datetime.today()}')


n=0
for _id in ids:
    print(n, '='*80)
    if n%5 == 0:
        clear_output(wait=True)
    doc = re_analyze_contract(ObjectId(_id))
    n+=1
    

    
logger.info(f're-analyse end  {datetime.today()}')
print( "delta:", datetime.today() - s)

# %%
load_docs_data(ids, df, ' _new')
df['Предмет изменился'] = df['subject _old']!=df['subject _new']
df = df.sort_values(['subject _old', 'subject quote _old', 'analyze_timestamp _new'])

# %%
df

# %%
df.to_csv('495-contracts-re-analyze-subj.csv')

# %%
errors_report_file_prefix = "495_markup_errors"
errors_report_metric_prefix = "495"
user_docs_ids = ids
# %run -i -t validate_markup.ipynb
del user_docs_ids
